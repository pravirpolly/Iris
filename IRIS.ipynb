# %%
import pandas as pd
iris = pd.read_csv (r'C:\\Users\\USER\\Desktop\\Python\Iris.csv')
print (iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.info()
iris.shape
iris.columns
iris.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
iris.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris.isnull() .sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# scatter plot
iris.plot(kind="scatter", x="SepalLengthCm", y= "SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
print (iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Joint Plot
sns.jointplot( data=iris,x="SepalLengthCm", y="SepalWidthCm", size=5)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\axisgrid.py:2015: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Density Plot : KDE
sns.kdeplot(data= iris, x="SepalLengthCm", y="SepalWidthCm", size=5)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'size'
#   cset = contour_func(
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
# Facet Grid
sns.FacetGrid(iris, hue="Species", palette="husl",height=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %%
# Box Plot
sns.boxplot(data=iris, x= 'Species', y= 'SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
# Box Plot
sns.boxplot(data=iris, x= 'Species', y= 'SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
# Box Plot
sns.boxplot(data=iris, x= 'Species', y= 'PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
# Violin Plot
sns.violinplot(data=iris, x= 'Species', y= 'PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
# Pair Plot
sns.pairplot(iris.drop("Id", axis=1), hue='Species', palette="husl", height=3)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail(      )
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
sns.pairplot(iris.drop("Id", axis=1), hue='Species', palette="husl", height=1)

# %%
iris.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# Heat Map
plt.figure(figsize=(12,8))
sns.heatmap(iris.corr(), annot=True, cmap='Dark2_r', linewidths = 2)
plt.show()

# %%
plt.figure(figsize=(25,15))

plt.subplot(2,2,1)
sns.histplot(iris['SepalLengthCm'], color = 'red', kde = True).set_title('SepalLengthCm Interval and Counts')

plt.subplot(2,2,2)
sns.histplot(iris['SepalWidthCm'], color = 'green', kde = True).set_title('SepalWidthCm Interval and Counts')

plt.subplot(2,2,3)
sns.histplot(iris['PetalLengthCm'], kde = True, color = 'blue').set_title('PetalLengthCm Interval and Counts')

plt.subplot(2,2,4)
sns.histplot(iris['PetalWidthCm'], kde = True, color = 'black').set_title('PetalWidthCm Interval and Counts')
# Out:
# Text(0.5, 1.0, 'PetalWidthCm Interval and Counts')

# %%
plt.figure(figsize=(10,10))
sns.histplot(iris['SepalLengthCm'], color = 'red', kde = True).set_title('SepalLengthCm vs Counts')
# Out:
# Text(0.5, 1.0, 'SepalLengthCm vs Counts')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.histplot(iris['SepalLengthCm'], color = 'red', kde = True).set_title('SepalLengthCm vs Counts')
plt.subplot(2,2,2)
sns.histplot(iris['SepalWidthCm'], color = 'blue', kde = True).set_title('SepalWidthCm vs Counts')
plt.subplot(2,2,3)
sns.histplot(iris['PetalWidthCm'], color = 'green', kde = True).set_title('PetalWidthCm vs Counts')
plt.subplot(2,2,4)
sns.histplot(iris['PetalLengthCm'], color = 'grey', kde = True).set_title('PetalLengthCm vs Counts')
# Out:
# Text(0.5, 1.0, 'PetalLengthCm vs Counts')

# %%
# DATA VISUALIZATION USING BAR
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.barplot(x = 'Species', y = 'SepalLengthCm', data = iris, palette="cubehelix")
plt.subplot(2,2,2)
sns.barplot(x = 'Species', y = 'SepalWidthCm', data = iris, palette="Oranges")
plt.subplot(2,2,3)
sns.barplot(x = 'Species', y = 'PetalLengthCm', data = iris, palette="Oranges")
plt.subplot(2,2,4)
sns.barplot(x = 'Species', y = 'PetalWidthCm', data = iris, palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>
